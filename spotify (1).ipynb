# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style

# %%
d=pd.read_csv(r'SpotifyTopSongsByCountry - May 2020.csv')
d
# Out:
#       Country Continent  Rank                            Title  \
# 0      Global    Global     1  Rain On Me (with Ariana Grande)
# 1      Global    Global     2                  Blinding Lights
# 2      Global    Global     3     ROCKSTAR (feat. Roddy Ricch)
# 3      Global    Global     4            Roses - Imanbek Remix
# 4      Global    Global     5                     Toosie Slide
# ...       ...       ...   ...                              ...
# 3145  Vietnam      Asia    46                       ĐÃ TỪNG LÀ
# 3146  Vietnam      Asia    47                Mượn Rượu Tỏ Tình
# 3147  Vietnam      Asia    48                     Ngày Tận Thế
# 3148  Vietnam      Asia    49                     Đi Đu Đưa Đi
# 3149  Vietnam      Asia    50                  Blinding Lights
#
#                          Artists                            Album  Explicit  \
# 0       Lady Gaga, Ariana Grande  Rain On Me (with Ariana Grande)         0
# ...

# %%
d.head(5)
# Out:
#   Country Continent  Rank                            Title  \
# 0  Global    Global     1  Rain On Me (with Ariana Grande)
# 1  Global    Global     2                  Blinding Lights
# 2  Global    Global     3     ROCKSTAR (feat. Roddy Ricch)
# 3  Global    Global     4            Roses - Imanbek Remix
# 4  Global    Global     5                     Toosie Slide
#
#                     Artists                            Album  Explicit  \
# 0  Lady Gaga, Ariana Grande  Rain On Me (with Ariana Grande)         0
# 1                The Weeknd                      After Hours         0
# 2       DaBaby, Roddy Ricch                 BLAME IT ON BABY         1
# 3        SAINt JHN, Imanbek            Roses (Imanbek Remix)         1
# 4                     Drake             Dark Lane Demo Tapes         1
#
#   Duration
# 0     3:02
# 1     3:20
# 2     3:01
# 3     2:56
# 4     4:07

# %%
d.shape
# Out:
# (3150, 8)

# %%
d.Country.unique()
# Out:
# array(['Global', 'Argentina', 'Australia', 'Austria', 'Belgium',
#        'Bolivia', 'Brazil', 'Bulgaria', 'Canada', 'Chile', 'Colombia',
#        'Costa Rica', 'Czech Republic', 'Denmark', 'Dominican Republic',
#        'Ecuador', 'El Salvador', 'Estonia', 'Finland', 'France',
#        'Germany', 'Greece', 'Guatemala', 'Honduras', 'Hong Kong',
#        'Hungary', 'Iceland', 'India', 'Indonesia', 'Ireland', 'Israel',
#        'Italy', 'Japan', 'Latvia', 'Lithuania', 'Luxembourg', 'Malaysia',
#        'Malta', 'Mexico', 'Netherlands', 'New Zealand', 'Nicaragua',
#        'Norway', 'Panama', 'Paraguay', 'Peru', 'Philippines', 'Poland',
#        'Portugal', 'Romania', 'Singapore', 'Slovakia', 'South Africa',
#        'Spain', 'Sweden', 'Switzerland', 'Taiwan', 'Thailand', 'Turkey',
#        'United Kingdom', 'United States', 'Uruguay', 'Vietnam'],
#       dtype=object)

# %%
d.Country!= "Global"
d
# Out:
#       Country Continent  Rank                            Title  \
# 0      Global    Global     1  Rain On Me (with Ariana Grande)
# 1      Global    Global     2                  Blinding Lights
# 2      Global    Global     3     ROCKSTAR (feat. Roddy Ricch)
# 3      Global    Global     4            Roses - Imanbek Remix
# 4      Global    Global     5                     Toosie Slide
# ...       ...       ...   ...                              ...
# 3145  Vietnam      Asia    46                       ĐÃ TỪNG LÀ
# 3146  Vietnam      Asia    47                Mượn Rượu Tỏ Tình
# 3147  Vietnam      Asia    48                     Ngày Tận Thế
# 3148  Vietnam      Asia    49                     Đi Đu Đưa Đi
# 3149  Vietnam      Asia    50                  Blinding Lights
#
#                          Artists                            Album  Explicit  \
# 0       Lady Gaga, Ariana Grande  Rain On Me (with Ariana Grande)         0
# ...

# %%
continent_value_counts = (d["Continent"].value_counts()/50).astype("int32")
continent_value_counts = continent_value_counts.drop("Global")
continent_value_counts
# Out:
# Europe           29
# Asia             11
# North America    10
# South America     9
# Australia         2
# Africa            1
# Name: Continent, dtype: int32

# %%
ax=plt.axes()
ax.set_facecolor('k')
plt.barh([contient_values_counts],label='ISP',color='r',height=continent_values_counts)
plt.legend()
plt.show
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-bdc35e03ff9e> in <module>
#       1 ax=plt.axes()
#       2 ax.set_facecolor('k')
# ----> 3 plt.barh([contient_values_counts],label='ISP',color='r',height=continent_values_counts)
#       4 plt.legend()
#       5 plt.show
#
# NameError: name 'contient_values_counts' is not defined

# %%
height = continent_value_counts.values
bars = continent_value_counts.index
y_pos = range(0,12,2)

fig = plt.figure(figsize=[13,7], frameon=False)
ax = fig.gca()
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.spines["left"].set_color("#424242")
ax.spines["bottom"].set_color("#424242")

plt.bar(y_pos, height, color="#1db954", width=1.2)
 
plt.xticks(y_pos, bars, color="#424242")
plt.yticks(color="#424242")
for i, v in enumerate(height):
    ax.text((i)*2 - 0.1, v+0.5, str(v), color='#424242')
plt.title("Number of countries in each continent", y=-0.15)

plt.show()

# %%
x = np.array(["Continent"])
y = np.array(["Explicit"])
plt.plot(x,y)
plt.show()

# %%
pd.crosstab(d['Continent'],d['Explicit'],margins=True)
# Out:
# Explicit          0     1   All
# Continent
# Africa           27    23    50
# Asia            448   102   550
# Australia        56    44   100
# Europe          864   586  1450
# Global           27    23    50
# North America   303   197   500
# South America   326   124   450
# All            2051  1099  3150

# %%
pd.crosstab(d['Continent'],d['Country'],margins=True)
# Out:
# Country        Argentina  Australia  Austria  Belgium  Bolivia  Brazil  \
# Continent
# Africa                 0          0        0        0        0       0
# Asia                   0          0        0        0        0       0
# Australia              0         50        0        0        0       0
# Europe                 0          0       50       50        0       0
# Global                 0          0        0        0        0       0
# North America          0          0        0        0        0       0
# South America         50          0        0        0       50      50
# All                   50         50       50       50       50      50
#
# Country        Bulgaria  Canada  Chile  Colombia  ...  Sweden  Switzerland  \
# Continent                                         ...
# Africa                0       0      0         0  ...       0            0
# Asia                  0       0      0         0  ...       0            0
# ...

# %%
Artists = []
for i in d["Artists"]:
    a = i.split(", ")
    Artists = Artists + a

# %%
len(Artists)
# Out:
# 5056

# %%
d .boxplot(column='Explicit')
# Out:
# <AxesSubplot:>

# %%
d .boxplot(column='Explicit')
# Out:
# <AxesSubplot:>

# %%
pd.crosstab(d['Continent'],d['Duration'].max(), margins=True)
# Out:
# col_0          6:47   All
# Continent
# Africa           50    50
# Asia            550   550
# Australia       100   100
# Europe         1450  1450
# Global           50    50
# North America   500   500
# South America   450   450
# All            3150  3150

# %%
pd.crosstab(d['Continent'],d['Explicit'],margins=True)
# Out:
# Explicit          0     1   All
# Continent
# Africa           27    23    50
# Asia            448   102   550
# Australia        56    44   100
# Europe          864   586  1450
# Global           27    23    50
# North America   303   197   500
# South America   326   124   450
# All            2051  1099  3150

# %%
pd.crosstab(d['Continent'],d['Explicit'])
# Out:
# Explicit         0    1
# Continent
# Africa          27   23
# Asia           448  102
# Australia       56   44
# Europe         864  586
# Global          27   23
# North America  303  197
# South America  326  124

# %%
e=pd.crosstab(d['Continent'],d['Explicit'])
e
# Out:
# Explicit         0    1
# Continent
# Africa          27   23
# Asia           448  102
# Australia       56   44
# Europe         864  586
# Global          27   23
# North America  303  197
# South America  326  124

# %%
x = ['e']

plt.bar(x,  color = "red",height=1000)
plt.show()

# %%
e=pd.crosstab(d['Continent'],d['Explicit'])
e
# Out:
# Explicit         0    1
# Continent
# Africa          27   23
# Asia           448  102
# Australia       56   44
# Europe         864  586
# Global          27   23
# North America  303  197
# South America  326  124

# %%
e=pd.crosstab(d['Continent'],d['Country'],value_counts)
e
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-8c3508fcbd47> in <module>
# ----> 1 e=pd.crosstab(d['Continent'],d['Country'],value_counts)
#       2 e
#
# NameError: name 'value_counts' is not defined

# %%
height = e.values
bars = e.index
x=['e']
plt.title("Number of countries in each continent")
plt.bar(x, color = "#4CAF50",height=['e'])
plt.show()
